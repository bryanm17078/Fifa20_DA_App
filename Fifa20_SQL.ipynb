# %%
#Importing the libraries
import mysql.connector
import pandas as pd
import sqlalchemy 
from sqlalchemy import create_engine
import pymysql
from sqlalchemy.types import INTEGER
from sqlalchemy.types import VARCHAR
from sqlalchemy.types import DATE
from sqlalchemy.types import DECIMAL

# %%
engine = sqlalchemy.create_engine('mysql+mysqlconnector://root:Msqli1m.@localhost:3306/fifa20')

# %%
mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  passwd="Msqli1m.",
  database='fifa20'
)

#Creating a cursor object using the cursor() method
cursor = mydb.cursor()

#Altering the database to allow more uft-8 characters
cursor.execute("ALTER DATABASE `%s` CHARACTER SET 'utf8' COLLATE 'utf8_unicode_ci'" % 'fifa20')


#Closing the connection
mydb.close()

# %%
#Getting the table ready to be put into the database
#Removing the stats to put in individual dataframe
players=pd.read_csv('players_20.csv')
players.drop(players.iloc[:, 25:69], inplace=True, axis=1)

players['team_position']=([x.split(',')[0] for x in players['player_positions']])

# %%
#Separating the stats in individual dataframe with sofifaid
play=pd.read_csv('players_20.csv')
so=play.copy(deep=False)
so.drop(so.iloc[:, 1:25], inplace=True, axis=1)
att=so.drop(columns=['skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control','movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes'])
skill=so.drop(columns=['attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys','movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes'])
mov=so.drop(columns=['attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control','power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes'])
power=so.drop(columns=['attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control','movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes'])
ment=so.drop(columns=['attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control','movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','defending_marking','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes'])
defend=so.drop(columns=['attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control','movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes'])
gk=so.drop(columns=['attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control','movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking','defending_standing_tackle','defending_sliding_tackle'])

# %%
#Creating a league table to put in the database for the transfers
team=pd.read_csv('finalteamdata_fifa2020.csv',dtype={'Budget':str})
uniquel=(team.League.unique())
leagueid=range(1,len(uniquel))
leaguedf=pd.DataFrame(zip(uniquel,leagueid),columns=['League','League_ID'])
team=(team.merge(leaguedf))
#Cleaning up the table
team=team.drop(columns=['Unnamed: 0','Team'])
team['Dprestige']=team['Dprestige'].str.replace(']','')
print display(team)
# Out:
#                                                    URL      ID Dprestige  \
# 0        https://sofifa.com/team/22/borussia-dortmund/      22         7
# 1      https://sofifa.com/team/32/bayer-04-leverkusen/      32         6
# 2        https://sofifa.com/team/21/fc-bayern-munchen/      21         9
# 3            https://sofifa.com/team/34/fc-schalke-04/      34         6
# 4           https://sofifa.com/team/175/vfl-wolfsburg/     175         4
# 5           https://sofifa.com/team/112172/rb-leipzig/  112172         6
# 6    https://sofifa.com/team/1824/eintracht-frankfurt/    1824         5
# 7              https://sofifa.com/team/166/hertha-bsc/     166         4
# 8    https://sofifa.com/team/23/borussia-monchengla...      23         5
# 9          https://sofifa.com/team/100409/fc-augsburg/  100409         3
# 10        https://sofifa.com/team/38/sv-werder-bremen/      38         4
# 11               https://sofifa.com/team/31/1-fc-koln/      31         3
# ...

# %%
#Reading the player table to SQL
dbConnection=engine.connect()
players.to_sql('players',dtype={'sofifa_id': INTEGER(),'player_url': VARCHAR(512),'short_name': VARCHAR(50),'long_name': VARCHAR(50),'age': INTEGER(),'dob': DATE(),'height_cm': INTEGER(),'weight_kg': INTEGER(),'nationality': VARCHAR(50),'club': VARCHAR(50), 'overall': INTEGER(),'potential': INTEGER(),'value_eur': DECIMAL(15,4),'wage_eur': DECIMAL(15,4),'player_positions': VARCHAR(20),'preferred_foot': VARCHAR(20),'weak_foot': INTEGER(),'skill_moves': INTEGER(),'work_rate': VARCHAR(20),'release_clause_eur': DECIMAL(15,4),'team_position': VARCHAR(20)},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
#Reading the player stats (attack,skill,movement,power,mentality,defend and goalkeeping) tables to SQL
att.to_sql('attack',dtype={'sofifa_id': INTEGER(),'attacking_crossing': INTEGER(),'attacking_finishing': INTEGER(),'attacking_heading_accuracy': INTEGER(),'attacking_short_passing': INTEGER(),'attacking_volleys': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
skill.to_sql('skill',dtype={'sofifa_id': INTEGER(),'skill_dribbling': INTEGER(),'skill_curve': INTEGER(),'skill_fk_accuracy': INTEGER(),'skill_long_passing': INTEGER(),'skill_ball_control': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
mov.to_sql('movement',dtype={'sofifa_id': INTEGER(),'movement_acceleration': INTEGER(),'movement_sprint_speed': INTEGER(),'movement_agility': INTEGER(),'movement_reactions': INTEGER(),'movement_balance': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
power.to_sql('power',dtype={'sofifa_id': INTEGER(),'power_shot_power': INTEGER(),'power_jumping': INTEGER(),'power_stamina': INTEGER(),'power_strength': INTEGER(),'power_long_shot': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
ment.to_sql('mentality',dtype={'sofifa_id': INTEGER(),'mentality_aggression': INTEGER(),'mentality_interceptions': INTEGER(),'mentality_positioning': INTEGER(),'mentality_vision': INTEGER(),'mentality_penalties': INTEGER(),'mentality_composure': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
defend.to_sql('defend',dtype={'sofifa_id': INTEGER(),'defending_marking': INTEGER(),'defending_standing_tackle': INTEGER(),'defending_sliding_tackle': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
gk.to_sql('gk',dtype={'sofifa_id':INTEGER(),'goalkeeping_diving': INTEGER(),'goalkeeping_handling': INTEGER(),'goalkeeping_kicking': INTEGER(), 'goalkeeping_positioning': INTEGER(),'goalkeeping_reflexes': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
dbConnection.close()

# %%
#Reading the league and team table to SQL
dbConnection=engine.connect()
team.to_sql('teams',dtype={'ID': INTEGER(),'URL':VARCHAR(512),'Dprestige': INTEGER(),'Iprestige': INTEGER(),'Attack': INTEGER(),'Midfield': INTEGER(), 'Defence': INTEGER(), 'Budget':VARCHAR(75),'Teams':VARCHAR(50),'League_ID': INTEGER()},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
leaguedf.to_sql('leagues',dtype={'League_ID': INTEGER(),'League':VARCHAR(75)},con=dbConnection,index=False, if_exists='fail',chunksize=1000);
dbConnection.close()
